# %% [markdown]
# <a href="https://colab.research.google.com/github/Navaneeth272001/GAN-Based-X-Ray-Artifact-Detection-and-Removal/blob/main/GAN_Based_X_Ray_Artifact_Removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notes
# Let's start with a simple dataset to ensure that the model works and to prove that this approach actually is a possible solution. After that we can try out a more complicated dataset which has more variations.
#
# ## Simple Dataset
# - `Thickness` of the grid lines is constant throughout the dataset
# - `Distance` of the grid lines is constant throughout the dataset
# - `Intensity` of the grid lines is constant throughout the dataset
# - `Angle` of the grid lines is either 0°(`horizontal`) or 90°(`veritcal`)
#
# ## Complex Dataset
# - `Thickness` of the grid lines vary throughout the dataset but constant for one X-ray
# - `Distance` of the grid lines vary throughout the dataset but constant for one X-ray
# - `Intensity` of the grid lines vary throughout the dataset but constant for one X-ray
# - `Angle` of the grid lines vary between 0° and 90° but constant for one X-ray

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Simple Dataset Preparation

# %%
"""
PARAMETERS FOR THE DATASET CREATION
"""

THICKNESS = 2  # in opencv scale (can be thought of pixels)
DISTANCE = 5  # in pixels
INTENSITY = 15  # this value will be subracted to the R, G, B channels
ANGLES = ["0", "90"]  # angle for one X-ray is randomly sampled from this list

# %%
"""
import neccessary packages
"""

# built-in packages
import glob
import random
from typing import Tuple

# third-party packages
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
"""
Return a binary image containing horizontal grid lines
"""

def get_horizontal_grid(nrows: int, ncols: int) -> np.ndarray:
    binary_mask = np.zeros((nrows, ncols, 1), np.uint8)

    for row_idx in range(nrows):
        if row_idx % DISTANCE == 0:
            cv2.line(binary_mask, (0, row_idx), (ncols, row_idx), 255, THICKNESS)

    return binary_mask

# %%
"""
Return a binary image containing vertical grid lines
"""

def get_vertical_grid(nrows: int, ncols: int) -> np.ndarray:
    binary_mask = np.zeros((nrows, ncols, 1), np.uint8)

    for col_idx in range(ncols):
        if col_idx % DISTANCE == 0:
            cv2.line(binary_mask, (col_idx, 0), (col_idx, nrows), 255, THICKNESS)

    return binary_mask

# %%
"""
ONLY FOR VERTICAL AND HORIZONTAL GRIDS

Draw grid lines on the given image.

Return a new image with grid lines and it's corresponding binary grid.
"""

def draw_grid_lines(image: np.ndarray):
    nrows, ncols, nchannels = image.shape

    # generate the binary grid mask
    angle = random.choice(ANGLES)
    if angle == "0":
        binary_grid = get_horizontal_grid(nrows, ncols)
    elif angle == "90":
        binary_grid = get_vertical_grid(nrows, ncols)
    else:
        raise Exception("Grid lines with angle other than 0° and 90° are not implemented")

    # apply the grid mask on the given image
    intensities = np.zeros((image.shape)) - INTENSITY
    grid_masked_image = cv2.add(image, intensities, mask=binary_grid, dtype=cv2.CV_8U)
    bg_image = cv2.bitwise_and(image, image, mask=cv2.bitwise_not(binary_grid))

    grid_image = cv2.add(bg_image, grid_masked_image)

    return grid_image, binary_grid

# %%
orig_image = cv2.imread("data/trainB/0.png")

out, _ = draw_grid_lines(orig_image)

cv2_imshow(out)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-7ba25db81e78> in <cell line: 3>()
#       1 orig_image = cv2.imread("data/trainB/0.png")
#       2
# ----> 3 out, _ = draw_grid_lines(orig_image)
#       4
#       5 cv2_imshow(out)
#
# <ipython-input-6-d920d5d69341> in draw_grid_lines(image)
#       8
#       9 def draw_grid_lines(image: np.ndarray):
# ---> 10     nrows, ncols, nchannels = image.shape
#      11
#      12     # generate the binary grid mask
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# # Complex Dataset Preparation

# %%
"""
PARAMETERS FOR THE DATASET CREATION
"""

THICKNESS_RANGE = [1, 3]  # in opencv scale (can be thought of pixels)
DISTANCE_RANGE = [7, 9]  # in pixels
INTENSITY_RANGE = [10, 20]  # this value will be subracted to the R, G, B channels

# %%
"""
import neccessary packages
"""

# built-in packages
import glob
import random
from typing import Tuple

# third-party packages
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
"""
Return a binary image containing grid lines in random angle
"""

def get_random_grid(nrows: int, ncols: int) -> np.ndarray:
    DISTANCE = np.random.randint(DISTANCE_RANGE[0], DISTANCE_RANGE[1] + 1)
    THICKNESS = np.random.randint(THICKNESS_RANGE[0], THICKNESS_RANGE[1] + 1)

    binary_mask = np.zeros((nrows, ncols, 1), np.uint8)

    i = np.random.randint(0, nrows)
    j = np.random.randint(0, ncols)

    count = 0
    while i - count >= 0 or j - count >= 0:
        if count % DISTANCE != 0:
            count += 1
            continue

        p1 = (0, i - count)
        p2 = (ncols, j - count)

        cv2.line(binary_mask, p1, p2, 255, THICKNESS)

        count += 1

    count = 0
    while i + count <= nrows or j + count <= nrows:
        if count % DISTANCE != 0:
            count += 1
            continue

        p1 = (0, i + count)
        p2 = (ncols, j + count)

        cv2.line(binary_mask, p1, p2, 255, THICKNESS)

        count += 1

    return binary_mask

# %%
"""
Draw grid lines on the given image.

Return a new image with grid lines and it's corresponding binary grid.
"""

def draw_grid_lines(image: np.ndarray):
    INTENSITY = np.random.randint(INTENSITY_RANGE[0], INTENSITY_RANGE[1] + 1)
    nrows, ncols, nchannels = image.shape

    # generate the binary grid mask
    binary_grid = get_random_grid(nrows, ncols)

    # apply the grid mask on the given image
    intensities = np.zeros((image.shape)) - INTENSITY
    grid_masked_image = cv2.add(image, intensities, mask=binary_grid, dtype=cv2.CV_8U)
    bg_image = cv2.bitwise_and(image, image, mask=cv2.bitwise_not(binary_grid))

    grid_image = cv2.add(bg_image, grid_masked_image)

    return grid_image, binary_grid

# %%
orig_image = cv2.imread("0.png")
orig_image = cv2.resize(orig_image, (256, 256))

out, mask = draw_grid_lines(orig_image)

cv2_imshow(out)

# %% [markdown]
# # Generate Dataset

# %%
# copy source images
# !cp -R "/content/drive/MyDrive/GAN hack/images" .

# %%
"""
Utility function to draw grids on all images in the given source directory
and save it in the given out directory.
"""

def draw_grids(src_dir: str, out_dir: str) -> None:
    # iterate through the file names in the src dir
    image_paths = glob.glob(src_dir + "/*")
    for idx, image_path in enumerate(image_paths):
        orig_image = cv2.imread(image_path)
        grid_image, grid = draw_grid_lines(orig_image)

        file_name = f"{out_dir}/{idx}.png"
        cv2.imwrite(file_name, grid_image)

# %%
# Generate B domain images (without grid) for train & test
images = glob.glob("images/*")
images = random.sample(images, 3300)

train_images = images[:3000]
test_images = images[3000:]

for idx, image_path in enumerate(train_images):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (256, 256))
    cv2.imwrite(f"data/trainB/{idx}.png", image)

for idx, image_path in enumerate(test_images):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (256, 256))
    cv2.imwrite(f"data/testB/{idx}.png", image)

# %%
# Generate A domain images (with grid) for train & test
images = glob.glob("images/*")
images = random.sample(images, 3300)

train_images = images[:3000]
test_images = images[3000:]

for idx, image_path in enumerate(train_images):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (256, 256))
    grid_image, _ = draw_grid_lines(image)
    cv2.imwrite(f"data/trainA/{idx}.png", grid_image)

for idx, image_path in enumerate(test_images):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (256, 256))
    grid_image, _ = draw_grid_lines(image)
    cv2.imwrite(f"data/testA/{idx}.png", grid_image)

# %%
# !zip -rq complex_data.zip data

# %%
# !cp complex_data.zip "/content/drive/MyDrive/GAN hack/"

# %% [markdown]
# # Training

# %%
# load the data from drive
# !cp "/content/drive/MyDrive/GAN hack/complex_data.zip" .
# !unzip -q complex_data.zip

# %%
# !cp "/content/drive/MyDrive/GAN hack/checkpoints.zip" .
# !unzip -q checkpoints.zip

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix.git
# !pip install -r pytorch-CycleGAN-and-pix2pix/requirements.txt
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2513, done.
# remote: Total 2513 (delta 0), reused 0 (delta 0), pack-reused 2513
# Receiving objects: 100% (2513/2513), 8.20 MiB | 7.07 MiB/s, done.
# Resolving deltas: 100% (1575/1575), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from -r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (2.0.0+cu118)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from -r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 2)) (0.15.1+cu118)
# Collecting dominate>=2.4.0
#   Downloading dominate-2.7.0-py2.py3-none-any.whl (29 kB)
# Collecting visdom>=0.1.8.8
#   Downloading visdom-0.2.4.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 38.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting wandb
#   Downloading wandb-0.15.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 76.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (3.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (3.25.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 2)) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from visdom>=0.1.8.8->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 4)) (1.10.1)
# Requirement already satisfied: tornado in /usr/local/lib/python3.10/dist-packages (from visdom>=0.1.8.8->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 4)) (6.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from visdom>=0.1.8.8->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 4)) (1.16.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from visdom>=0.1.8.8->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 5)) (5.9.5)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 5)) (3.20.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.21.1-py2.py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 5)) (6.0)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 5)) (8.1.3)
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 28.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 5)) (67.7.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 2)) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 2)) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (2.1.2)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->-r pytorch-CycleGAN-and-pix2pix/requirements.txt (line 1)) (1.3.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: visdom, pathtools
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408216 sha256=0f2fcb5bfef6cc01f64ea466557b153583d5b6d1e18c00371dc37e2120049546
#   Stored in directory: /root/.cache/pip/wheels/42/29/49/5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=7eb2c497a653ab1d198ceac578a37a47c61efeb53bc1e031462318d07dbd1a6a
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built visdom pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, jsonpointer, dominate, docker-pycreds, jsonpatch, gitdb, visdom, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 dominate-2.7.0 gitdb-4.0.10 jsonpatch-1.32 jsonpointer-2.3 pathtools-0.1.2 sentry-sdk-1.21.1 setproctitle-1.3.2 smmap-5.0.0 visdom-0.2.4 wandb-0.15.0

# %%
# TRAINING

# !python pytorch-CycleGAN-and-pix2pix/train.py --dataroot ./data --name xray_cyclegan --model cycle_gan --display_id -1  --display_port 8097 --display_server http://localhost --save_epoch_freq 1 --epoch_count 89 --continue_train
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: ./data                        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: -1                            	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count:
# (epoch: 90, iters: 2600, time: 0.655, data: 0.002) D_A: 0.132 G_A: 0.483 cycle_A: 0.295 idt_A: 0.105 D_B: 0.038 G_B: 0.568 cycle_B: 0.278 idt_B: 0.171
# (epoch: 90, iters: 2700, time: 0.656, data: 0.004) D_A: 0.016 G_A: 0.951 cycle_A: 0.375 idt_A: 0.207 D_B: 0.046 G_B: 0.865 cycle_B: 0.431 idt_B: 0.256
# (epoch: 90, iters: 2800, time: 0.657, data: 0.002) D_A: 0.003 G_A: 0.894 cycle_A: 0.303 idt_A: 0.157 D_B: 0.019 G_B: 0.714 cycle_B: 0.343 idt_B: 0.153
# (epoch: 90, iters: 2900, time: 0.652, data: 0.002) D_A: 0.001 G_A: 1.039 cycle_A: 0.343 idt_A: 0.142 D_B: 0.071 G_B: 0.759 cycle_B: 0.370 idt_B: 0.130
# (epoch: 90, iters: 3000, time: 1.357, data: 0.008) D_A: 0.001 G_A: 0.998 cycle_A: 0.381 idt_A: 0.134 D_B: 0.027 G_B: 0.736 cycle_B: 0.325 idt_B: 0.164
# saving the model at the end of epoch 90, iters 6000
# End of epoch 90 / 200 	 Time Taken: 1593 sec
# learning rate 0.0002000 -> 0.0002000
# (epoch: 91, iters: 100, time: 0.649, data: 0.167) D_A: 0.001 G_A: 1.021 cycle_A: 0.612 idt_A: 0.226 D_B: 0.013 G_B: 0.875 cycle_B: 0.556 idt_B: 0.130
# (epoch: 91, iters: 200, time: 0.655, data: 0.003) D_A: 0.001 G_A: 0.995 cycle_A: 0.593 idt_A: 0.271 D_B: 0.026 G_B: 1.167 cycle_B: 0.456 idt_B: 0.234
# (epoch: 91, iters: 300, time: 0.656, data: 0.002) D_A: 0.001 G_A: 0.995 cycle_A: 0.269 idt_A: 0.574 D_B: 0.022 G_B: 0.432 cycle_B: 1.090 idt_B: 0.123
# (epoch: 91, iters: 400, time: 1.587, data: 0.006) D_A: 0.001 G_A: 0.980 cycle_A: 0.311 idt_A: 0.220 D_B: 0.148 G_B: 0.373 cycle_B: 0.431 idt_B: 0.794
# (epoch: 91, iters: 500, time: 0.660, data: 0.010) D_A: 0.001 G_A: 0.968 cycle_A: 0.362 idt_A: 0.406 D_B: 0.211 G_B: 0.469 cycle_B: 0.783 idt_B: 0.236
# (epoch: 91, iters: 600, time: 0.653, data: 0.002) D_A: 0.005 G_A: 1.012 cycle_A: 0.626 idt_A: 0.147 D_B: 0.021 G_B: 0.857 cycle_B: 0.393 idt_B: 0.158
# (epoch: 91, iters: 700, time: 0.650, data: 0.002) D_A: 0.001 G_A: 0.983 cycle_A: 0.504 idt_A: 0.122 D_B: 0.022 G_B: 0.826 cycle_B: 0.276 idt_B: 0.178
# Traceback (most recent call last):
#   File "/content/pytorch-CycleGAN-and-pix2pix/train.py", line 52, in <module>
#     model.optimize_parameters()   # calculate loss functions, get gradients, update network weights
#   File "/content/pytorch-CycleGAN-and-pix2pix/models/cycle_gan_model.py", line 187, in optimize_parameters
#     self.backward_G()             # calculate gradients for G_A and G_B
#   File "/content/pytorch-CycleGAN-and-pix2pix/models/cycle_gan_model.py", line 171, in backward_G
#     self.loss_G_B = self.criterionGAN(self.netD_B(self.fake_A), True)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/parallel/data_parallel.py", line 169, in forward
#     return self.module(*inputs[0], **kwargs[0])
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content
real_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch080_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch081_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch080_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch080_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch081_real_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch081_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch081_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch080_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch081_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch082_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch083_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch080_real_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch081_idt_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch082_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch080_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch082_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch083_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch083_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch080_idt_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch082_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch083_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch080_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch083_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch081_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch082_idt_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch081_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch082_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch082_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch083_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/82_net_D_A.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/web/images/epoch085_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch084_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch084_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch087_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch087_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch085_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch087_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch084_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch086_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch084_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch085_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch084_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch087_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch087_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch087_real_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch087_idt_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch084_real_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch085_real_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch085_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch086_idt_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch084_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch086_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch086_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch085_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch086_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch085_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch084_idt_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch086_real_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch087_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch086_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch086_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch085_idt_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/85_net_D_A.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/86_net_D_A.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/84_net_G_B.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/85_net_G_B.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/86_net_G_A.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/84_net_D_A.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/86_net_D_B.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/85_net_G_A.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/85_net_D_B.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/84_net_G_A.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/86_net_G_B.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/84_net_D_B.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/web/images/epoch088_fake_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch088_idt_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch088_idt_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch088_rec_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch088_fake_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch088_rec_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch088_real_B.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/web/images/epoch088_real_A.png (deflated 0%)
# updating: checkpoints/xray_cyclegan/88_net_G_B.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/88_net_D_A.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/88_net_D_B.pth (deflated 7%)
# updating: checkpoints/xray_cyclegan/88_net_G_A.pth (deflated 7%)
#   adding: checkpoints/xray_cyclegan/90_net_G_B.pth (deflated 7%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch089_idt_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch090_fake_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch089_rec_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch089_real_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch091_fake_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch089_real_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch091_idt_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch090_idt_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch089_idt_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch090_rec_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch090_real_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch091_real_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch089_fake_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch089_fake_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch091_real_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch090_real_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch091_rec_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch091_rec_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch091_fake_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch090_fake_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch090_idt_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch090_rec_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch091_idt_A.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/web/images/epoch089_rec_B.png (deflated 0%)
#   adding: checkpoints/xray_cyclegan/90_net_D_B.pth (deflated 7%)
#   adding: checkpoints/xray_cyclegan/89_net_D_A.pth (deflated 7%)
#   adding: checkpoints/xray_cyclegan/89_net_D_B.pth (deflated 7%)
#   adding: checkpoints/xray_cyclegan/89_net_G_A.pth (deflated 7%)
#   adding: checkpoints/xray_cyclegan/90_net_D_A.pth (deflated 7%)
#   adding: checkpoints/xray_cyclegan/90_net_G_A.pth (deflated 7%)
#   adding: checkpoints/xray_cyclegan/89_net_G_B.pth (deflated 7%)

# %%
# TESTING

# !python pytorch-CycleGAN-and-pix2pix/test.py --dataroot test --name xray_cyclegan --model cycle_gan --no_dropout --num_test 1 --gpu_ids -1 --eval
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: test                          	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: True                          	[default: False]
#                   gpu_ids: -1                            	[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
#                      name: xray_cyclegan                 	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: resnet_9blocks
#                       ngf: 64
#                no_dropout: True
#                   no_flip: False
#                      norm: instance
#                  num_test: 1                             	[default: 50]
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# Traceback (most recent call last):
#   File "/content/pytorch-CycleGAN-and-pix2pix/test.py", line 50, in <module>
#     dataset = create_dataset(opt)  # create a dataset given opt.dataset_mode and other options
#   File "/content/pytorch-CycleGAN-and-pix2pix/data/__init__.py", line 57, in create_dataset
#     data_loader = CustomDatasetDataLoader(opt)
#   File "/content/pytorch-CycleGAN-and-pix2pix/data/__init__.py", line 73, in __init__
#     self.dataset = dataset_class(opt)
#   File "/content/pytorch-CycleGAN-and-pix2pix/data/unaligned_dataset.py", line 29, in __init__
#     self.A_paths = sorted(make_dataset(self.dir_A, opt.max_dataset_size))   # load images from '/path/to/data/trainA'
#   File "/content/pytorch-CycleGAN-and-pix2pix/data/image_folder.py", line 25, in make_dataset
#     assert os.path.isdir(dir), '%s is not a valid directory' % dir
# AssertionError: test/testA is not a valid directory
